# %% [markdown]
# # 자료형/숫자형

# %%
0o34
# Out:
# 28

# %%
# 0o는 8진수, 0x 는 16진수

# %%
0xA
# Out:
# 10

# %%
0x2A
# Out:
# 42

# %%
0x4D
# Out:
# 77

# %%
# '**'은 제곱 '%'는 나누고 난 후의 나머지 '//'은 나눈 후의 몫

# %%
# 문자열을 만들고 싶을 땐 '' 또는 "" 안에 쓰면 되다.

# %%
# 작은 따옴표를 쓰다가는 어퍼스트로피를 쓸 때 중복이 나서 에러가 나온다.
#큰 떠옴표도 인용문을 쓸 때 중복이 난다.
    #이럴때는 문자로 보일 '나 " 앞에 '\' 역슬래쉬를 넣어준다.

# %% [markdown]
# ### 줄바꿈을 하고 싶을 땐 \n html에서 <br>이랑 같은 역활

# %%
# \n은 이스케이프 코드 중 줄 바꿈 기능이다.

# %%
# \를 치는 걸로 출력물을 정리할 때 쓰는 코드가 이스케이프 코드이다.

# %%
# 자주 사용하는 것은 '\n', '\t', '\\', '\'', '\"' 이다.

# %%
multiline='''Life is too short'''

# %%
print(multiline)
# Out:
# Life is too short

# %%
print('='*30)

# %%
a='hi how are you thank you and you'
len(a)
# Out:
# 32

# %%
a[5]
# Out:
# 'w'

# %%
a[0]
# Out:
# 'h'

# %%
a[-4]
# Out:
# ' '

# %%
a[-1]
# Out:
# 'u'

# %%
a[:5]
# Out:
# 'hi ho'

# %%
a[6:9]
# Out:
# ' ar'

# %%
a[12:]
# Out:
# 'ou thank you and you'

# %%
a='20260227'
year=a[:4]
month=a[4:6]
date=a[6:]

# %%
year
# Out:
# '2026'

# %%
# 문자열은 '변경 불가능한 자료형'

# %%
# 문자열 양식은 같은데 값만 바꿀 수 있게 할려면 문자열 포매팅을 이용한다

# %%
'I ate %d bananas.'%4
# Out:
# 'I ate 4 bananas.'

# %%
# 숫자를 넣기 위해서는 %d 문자열을 넣기 위해서는 %s

# %%
a= 5
'you have a %d apples'%a
# Out:
# 'you have a 5 apples'

# %%
# 2개 이상의 값을 넣기 위해선 %( , ) 이런 식으로 쓰고 순서에 맞게 넣어주면 된다.

# %%
# %s 에는 숫자도 넣을 수 있다. 이 경우 자동으로 숫자를 문자열로 바꾸어 대입해 준다.

# %%
# %르 표시하고 싶으면 %%

# %%
"%10s"%'hi'
# Out:
# '        hi'

# %%
# .format()을 사용하면 {}안에 ()에 넣은 것으로 바꿀 수 있다.

# %%
# {:<10} 을 이용해서 문자 총 자릿수를 19으로 맞출 수있다.

# %%
# < 이면 왼쪽 정렬 > 이명 오른쪽 정렬로 해준다.

# %%
# 가운데 정렬은 ^ 이다.

# %%
# : 앞에 문자를 쓰면 공백을 그 문자로 채워준다.

# %%
"{:=^10}".format('hi')
# Out:
# '====hi===='

# %%
"{:a^10}".format('hi')
# Out:
# 'aaaahiaaaa'

# %%
"{:y<50}".format('wr')
# Out:
# 'wryyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyy'

# %%
# 리스트 안에는 어떠한 자료형도 포함 할 수 있다.

# %%
# str은 정수나 실수를 문자열로 바꾸어 주는 파이썬의 내장 함수이다.

# %%
# del은 요소 삭제
